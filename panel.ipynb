# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import os

from sed import SedProcessor
from sed.dataset import dataset
import numpy as np

# %matplotlib widget
import matplotlib.pyplot as plt

from lmfit.models import GaussianModel

# %%
beamtime_dir = "/asap3/flash/gpfs/pg2/2023/data/11017721"
if os.path.exists(beamtime_dir) and os.access(beamtime_dir, os.R_OK):
    path = beamtime_dir + "/raw/hdf/online-0/fl1user3" 
    buffer_path = beamtime_dir + "/processed/tutorial/"
else:
    dataset.get("W110") 
    path = dataset.dir
    buffer_path = path + "/processed/"

# %%
config_override = {
    "core": {
        "beamtime_id": 11017721,
        "paths": {
            "raw": path,
            "processed": buffer_path
        },
    },
}

# %%
config_file = Path('/home/abdelhak/sed/src/sed/config/flash_example_config.yaml')
assert config_file.exists(), f"Config file not found at {config_file}"

energy_cal = {
    "energy": {
        "calibration": {
            "E0": -132.47100427179566,
            "creation_date": '2024-11-30T20:47:03.305244',
            "d": 0.8096677238144319,
            "energy_scale": "kinetic",
            "t0": 4.0148196706891397e-07,
        },
        "offsets":{
            "constant": 1,
            "creation_date": '2024-11-30T21:17:07.762199',
            "columns": {
                "monochromatorPhotonEnergy": {
                    "preserve_mean": True,
                    "weight": -1,
                },
                "tofVoltage": {
                    "preserve_mean": True,
                    "weight": -1,
                },
            },
        },
    },
}

# %%
run_number = 49272
sp_49272 = SedProcessor(runs=[run_number], config=config_override, folder_config=energy_cal, system_config=config_file, verbose=True, panel=False)

sp_49272.add_jitter()
sp_49272.align_dld_sectors()
sp_49272.append_energy_axis()
sp_49272.add_energy_offset()
# Out:
# INFO - System config loaded from: [/home/abdelhak/sed/src/sed/config/flash_example_config.yaml]
# INFO - Default config loaded from: [/home/abdelhak/sed/src/sed/config/default.yaml]
# INFO - Panel dashboard is enabled
# INFO - Reading files: 0 new files of 11 total.
# loading complete in  0.75 s
# INFO - Creating beamtime dashboard with window=100, plot=True, pbar=False
# INFO - Using channels: ['trainId', 'pulseId', 'gmdBda', 'delayStage', 'bam']
# INFO - Applying filters: {'pulseId': (0.0, 500.0), 'dldPosX': (0.0, 1100.0), 'dldPosY': (0.0, 820.0)}
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d27c7d3a-19c9-40e6-989c-8c9492c411f8">Loading BokehJS ...</span>
#     </div>
#   <div id="dac53e77-5592-41a8-a68e-5f095a39f45e" data-root-id="p1559" style="display: contents;"></div>
# INFO - Beamtime dashboard automatically displayed
# INFO - add_jitter: Added jitter to columns ['dldPosX', 'dldPosY', 'dldTimeSteps'].
# INFO - Aligning 8s sectors of dataframe
# INFO - Dask DataFrame Structure:
#                trainId pulseId electronId  dldPosX  dldPosY dldTimeSteps      bam timeStamp monochromatorPhotonEnergy   gmdBda delayStage sampleBias tofVoltage extractorVoltage extractorCurrent cryoTemperature sampleTemperature dldTimeBinSize dldSectorID
# npartitions=11
#                 uint32   int64      int64  float64  float64      float32  float32   float64                   float32  float32    float32    float32    float32          float32          float32         float32           float32        float32        int8
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...
# ...                ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...
# Dask Name: assign, 31 graph layers
# INFO - Adding energy column to dataframe:
# INFO - Using energy calibration parameters generated on 11/30/2024, 20:47:03
# INFO - Dask DataFrame Structure:
#                trainId pulseId electronId  dldPosX  dldPosY dldTimeSteps      bam timeStamp monochromatorPhotonEnergy   gmdBda delayStage sampleBias tofVoltage extractorVoltage extractorCurrent cryoTemperature sampleTemperature dldTimeBinSize dldSectorID   energy
# npartitions=11
#                 uint32   int64      int64  float64  float64      float32  float32   float64                   float32  float32    float32    float32    float32          float32          float32         float32           float32        float32        int8  float64
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
# ...                ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
# Dask Name: assign, 46 graph layers
# INFO - Adding energy offset to dataframe:
# INFO - Using energy offset parameters generated on 11/30/2024, 21:17:07
# INFO - Energy offset parameters:
#    Constant: 1.0
#    Column[monochromatorPhotonEnergy]: Weight=-1.0, Preserve Mean: True, Reductions: None.
#    Column[tofVoltage]: Weight=-1.0, Preserve Mean: True, Reductions: None.
# INFO - Dask DataFrame Structure:
#                trainId pulseId electronId  dldPosX  dldPosY dldTimeSteps      bam timeStamp monochromatorPhotonEnergy   gmdBda delayStage sampleBias tofVoltage extractorVoltage extractorCurrent cryoTemperature sampleTemperature dldTimeBinSize dldSectorID   energy
# npartitions=11
#                 uint32   int64      int64  float64  float64      float32  float32   float64                   float32  float32    float32    float32    float32          float32          float32         float32           float32        float32        int8  float64
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
# ...                ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
#                    ...     ...        ...      ...      ...          ...      ...       ...                       ...      ...        ...        ...        ...              ...              ...             ...               ...            ...         ...      ...
# Dask Name: assign, 79 graph layers
